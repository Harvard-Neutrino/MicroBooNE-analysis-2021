# %%
import numpy as np
import pandas as pd
import yaml

# %%
covariance_matrices = {}
for i in range(0,21):
    index = f'{i:02d}'
    with open(fr'cov_lee_x_{index}.yaml') as file:
        # The FullLoader parameter handles the conversion from YAML
        covariance_matrices[index] = yaml.load(file, Loader=yaml.FullLoader)

# %%
pd.io.json.json_normalize(covariance_matrices['00'])
# Out:
# /var/folders/my/7j7cn6f92_z66yvbb11lgt2r0000gn/T/ipykernel_37810/1593152768.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   pd.io.json.json_normalize(covariance_matrices['00'])
#                                  dependent_variables  \
# 0  [{'header': {'name': 'Covariance'}, 'values': ...
#
#                                independent_variables
# 0  [{'header': {'name': 'bin index column'}, 'val...

# %%
covariance_matrices['00']['dependent_variables'][0]['values']
# Out:
# [{'value': 0.052},
#  {'value': 0.0288},
#  {'value': 0.0376},
#  {'value': 0.0444},
#  {'value': 0.0257},
#  {'value': 0.0846},
#  {'value': 0.0064},
#  {'value': 0.0531},
#  {'value': 0.0505},
#  {'value': -0.0045},
#  {'value': 0.0679},
#  {'value': 0.0197},
#  {'value': -0.043},
#  {'value': 0.007},
#  {'value': 0.0054},
#  {'value': 0.0186},
#  {'value': -0.0177},
#  {'value': 0.0228},
#  {'value': 0.0365},
#  {'value': 0.0027},
#  {'value': 0.0225},
#  {'value': -0.0289},
#  {'value': 0.0102},
#  {'value': 0.0072},
#  {'value': -0.0278},
#  {'value': -0.0425},
#  {'value': -0.0001},
#  {'value': -0.0},
#  {'value': 0.0117},
#  {'value': -0.0025},
#  {'value': 0.0063},
#  {'value': 0.0391},
#  {'value': 0.0032},
#  {'value': -0.0188},
#  {'value': -0.0121},
#  {'value': 0.0297},
#  {'value': 0.0546},
#  {'value': -0.0301},
#  {'value': 0.0108},
#  {'value': 0.034},
#  {'value': -0.0043},
#  {'value': -0.0217},
#  {'value': 0.0101},
#  {'value': 0.003},
#  {'value': 0.0139},
# ...
